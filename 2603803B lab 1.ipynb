# %% [markdown]
# # Week 1: getting started with anaconda, jupyter notebook and python

# %% [markdown]
# #### I chose to join this course because I find AI very interesting and believe that it is going to play a big part in our future

# %% [markdown]
# #### I have not had any experience with Python but have had experience with other systems which can be used to create content with codes.

# %% [markdown]
# ### Some things I expect to learn from this course are:
# #### - To learn in more depth about how an AI is created
# #### - To learn more about why AIs are created and what  they can be used for
# #### - To learn and develop my skills in programming

# %%
print ("Hello, World")
# Out:
# Hello, world

# %%
message = "Hello, Everyone"

print (message*3)
# Out:
# Hello, EveryoneHello, EveryoneHello, Everyone

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("925BbEnSKQw")
